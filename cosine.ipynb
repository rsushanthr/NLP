# %% [markdown]
# <a href="https://colab.research.google.com/github/rsushanthr/NLP/blob/main/cosine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_text(text):
  tokenize = word_tokenize(text)
  tokenize = [word.lower() for word in tokenize]
  stop_words = set(stopwords.words('english'))
  tokenize = [word for word in tokenize if word not in stop_words]

# %%
def preprocess_text(text):
  tokenize = word_tokenize(text)
  tokenize = [word.lower() for word in tokenize]
  stop_words = set(stopwords.words('english'))
  tokenize = [word for word in tokenize if word not in stop_words]
  lemmatizer = WordNetLemmatizer()
  tokenize = [lemmatizer.lemmatize(word) for word in tokenize]
  return " ".join(tokenize)

# %%
review1 = "I love this product! It is great."
review2 = "This product is not good. It is bad."

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)
print(a)
print(b)
# Out:
# love product ! great .
# product good . bad .

# %%
vectorizer = TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
print(vectors.toarray())
# Out:
# [[0.         0.         0.6316672  0.6316672  0.44943642]
#  [0.6316672  0.6316672  0.         0.         0.44943642]]

# %%
cosine_sim = cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosine_sim,3))
# Out:
# 0.202
